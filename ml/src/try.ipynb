# %%
import pandas as pd

# Load CSV file
df = pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\FISHGUARD\ml\data\raw\dataset_phishing.csv")

# View unique values in a specific column (e.g., 'url')
unique_values = df['status'].unique()
print(unique_values)
# Out:
# ['legitimate' 'phishing']
